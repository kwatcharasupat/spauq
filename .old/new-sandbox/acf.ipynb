# %%
import numpy as np

acf = np.load("/home/kwatchar3/bss_spatial_eval/results/20230131163154/acf.npz", allow_pickle=True)["arr_0"]

# %%
from matplotlib import pyplot as plt

# %%
for a in acf:
    n = a.shape[0]
    n = (n+1)//2
    a = a[n:n+64]
    plt.plot(np.arange(64)/16000, a)
    # plt.xscale('log', base=2)
    plt.show()
